# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('books.csv')
users = pd.read_csv('users.csv')
ratings = pd.read_csv('ratings.csv')
genre=pd.read_csv('GENRE.csv')
# Out:
# C:\Users\VG\AppData\Local\Temp\ipykernel_39832\119020395.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726   155061224            5
# 2   276727   446520802            0
# 3   276729  052165615X            3
# 4   276729   521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1048575, 3)
# (278858, 3)

# %%
genre.head()
# Out:
#         ISBN                              Genre  \
# 0  195153448             Non-fiction, mythology
# 1    2005018                   Fiction, romance
# 2   60973129               Non-fiction, history
# 3  374157065     Non-fiction, history, medicine
# 4  393045218  Non-fiction, history, archaeology
#
#                                           Book-Title           Book-Author  \
# 0                                Classical Mythology    Mark P. O. Morford
# 1                                       Clara Callan  Richard Bruce Wright
# 2                               Decision in Normandy          Carlo D'Este
# 3  Flu: The Story of the Great Influenza Pandemic...      Gina Bari Kolata
# 4                             The Mummies of Urumchi       E. J. W. Barber
#
#    Year-Of-Publication                   Publisher  \
# 0                 2002     Oxford University Press
# 1                 2001       HarperFlamingo Canada
# 2                 1991             HarperPerennial
# ...

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 72

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
ratings_with_name
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1          2313  034545104X            5
# 2          6543  034545104X            0
# 3          8680  034545104X            5
# 4         10314  034545104X            9
# ...         ...         ...          ...
# 941107   250764   440106575            0
# 941108   250764   451157516            0
# 941109   250764  048623715X            0
# 941110   250764   486256588            0
# 941111   250764   515069434            0
#
#                                                Book-Title        Book-Author  \
# 0                                    Flesh Tones: A Novel         M. J. Rose
# 1                                    Flesh Tones: A Novel         M. J. Rose
# 2                                    Flesh Tones: A Novel         M. J. Rose
# 3                                    Flesh Tones: A Novel         M. J. Rose
# 4                                    Flesh Tones: A Novel         M. J. Rose
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 230215                                 Ã?Â?l- Connection.            1
# 230216                                      Ã?Â?lpiraten.            2
# 230217                     Ã?Â?rger mit Produkt X. Roman.            4
# 230218                              Ã?Â?stlich der Berge.            2
# 230219                                  Ã?Â?thique en toc            2
#
# [230220 rows x 2 columns]

# %%
# Convert 'Book-Rating' to a numeric data type (handle non-numeric values with 'coerce')
ratings_with_name['Book-Rating'] = pd.to_numeric(ratings_with_name['Book-Rating'], errors='coerce')

# Calculate the average rating for each book title
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()

# Rename the 'Book-Rating' column to 'avg_rating'
avg_rating_df.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)

# Display the resulting DataFrame
print(avg_rating_df)
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...        2.25
# 1                                   Always Have Popsicles        0.00
# 2                    Apple Magic (The Collector's series)        0.00
# 3        Beyond IBM: Leadership Marketing and Finance ...        0.00
# 4        Clifford Visita El Hospital (Clifford El Gran...        0.00
# ...                                                   ...         ...
# 230215                                 Ã?Â?l- Connection.        0.00
# 230216                                      Ã?Â?lpiraten.        0.00
# 230217                     Ã?Â?rger mit Produkt X. Roman.        5.25
# 230218                              Ã?Â?stlich der Berge.        4.00
# 230219                                  Ã?Â?thique en toc        4.00
#
# [230220 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 230215                                 Ã?Â?l- Connection.            1
# 230216                                      Ã?Â?lpiraten.            2
# 230217                     Ã?Â?rger mit Produkt X. Roman.            4
# 230218                              Ã?Â?stlich der Berge.            2
# 230219                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0             2.25
# 1             0.00
# 2             0.00
# 3             0.00
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 76830        Harry Potter and the Goblet of Fire (Book 4)          346
# 76842   Harry Potter and the Prisoner of Azkaban (Book 3)          380
# 76834   Harry Potter and the Order of the Phoenix (Boo...          316
# 76822    Harry Potter and the Chamber of Secrets (Book 2)          501
# 182892  The Hobbit : The Enchanting Prelude to The Lor...          261
# 76853   Harry Potter and the Sorcerer's Stone (Harry P...          519
# 178857  The Fellowship of the Ring (The Lord of the Ri...          340
# 209806                              To Kill a Mockingbird          463
# 175236                                  The Da Vinci Code          828
# 172364                             The Catcher in the Rye          401
# 197170                            The Secret Life of Bees          704
# 179343                 The Five People You Meet in Heaven          392
# ...

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#                                             Book-Title         Book-Author  \
# 0         Harry Potter and the Goblet of Fire (Book 4)       J. K. Rowling
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)       J. K. Rowling
# 5    Harry Potter and the Order of the Phoenix (Boo...       J. K. Rowling
# 9     Harry Potter and the Chamber of Secrets (Book 2)       J. K. Rowling
# 12   The Hobbit : The Enchanting Prelude to The Lor...      J.R.R. TOLKIEN
# 13   Harry Potter and the Sorcerer's Stone (Harry P...       J. K. Rowling
# 15   The Fellowship of the Ring (The Lord of the Ri...      J.R.R. TOLKIEN
# 24                               To Kill a Mockingbird          Harper Lee
# 32                                   The Da Vinci Code           Dan Brown
# 38                              The Catcher in the Rye       J.D. Salinger
# 45                             The Secret Life of Bees       Sue Monk Kidd
# ...

# %% [markdown]
# # Collabarative Based Recommendation System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200 # We have taken average 200 because it is best fit as experimental data .
well_aware_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(well_aware_users)]

# %%
# Now we'll Do for Books , Till now it was for users.
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Moon', 'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wuthering Heights', 'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=603)

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
# Users wo hai jinhone 200 se jyada book padhi hai.
# Ratings Wo hai jinki 50 se jyada ratings hai.
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True) #Jaha bhi na waha zero.

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
# # Where Actual Recommendation's Logic Starts.

# %%
from sklearn.metrics.pairwise import cosine_similarity#as our book is under vector dimension of 1 to 810 Members.

# %%
similarity_scores = cosine_similarity(pt) # which gives eucledian distance between Two poins.

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg']]

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %% [markdown]
# # Genre-Wise Recommendation

# %%
genre=pd.read_csv('GENRE.csv')

# %%
genre
# Out:
#            ISBN                              Genre  \
# 0     195153448             Non-fiction, mythology
# 1       2005018                   Fiction, romance
# 2      60973129               Non-fiction, history
# 3     374157065     Non-fiction, history, medicine
# 4     393045218  Non-fiction, history, archaeology
# ...         ...                                ...
# 2994  679729259                            Classic
# 2995  452260116                            Classic
# 2996  812533550                    Science Fiction
# 2997   20442602                            Fantasy
# 2998  312978367                           Thriller
#
#                                              Book-Title           Book-Author  \
# 0                                   Classical Mythology    Mark P. O. Morford
# 1                                          Clara Callan  Richard Bruce Wright
# 2                                  Decision in Normandy          Carlo D'Este
# ...

# %%
genre_with_name = genre.merge(books,on='ISBN')

# %%
genre_with_name
# Out:
#            ISBN                              Genre  \
# 0     195153448             Non-fiction, mythology
# 1       2005018                   Fiction, romance
# 2      60973129               Non-fiction, history
# 3     374157065     Non-fiction, history, medicine
# 4     393045218  Non-fiction, history, archaeology
# ...         ...                                ...
# 2994  679729259                            Classic
# 2995  452260116                            Classic
# 2996  812533550                    Science Fiction
# 2997   20442602                            Fantasy
# 2998  312978367                           Thriller
#
#                                            Book-Title_x         Book-Author_x  \
# 0                                   Classical Mythology    Mark P. O. Morford
# 1                                          Clara Callan  Richard Bruce Wright
# 2                                  Decision in Normandy          Carlo D'Este
# ...

# %%
def recommend_genre(genre_name):
    # Filter books by the specified genre
    genre_books = genre_with_name[genre_with_name['Genre'] == genre_name]

    # Create a list of book titles in the specified genre
    genre_book_titles = genre_books['Book-Title'].tolist()

    recommended_books = []

    for book_title in genre_book_titles:
        # Check if the book is in the user-item ratings matrix
        if book_title in pt.index:
            # Get recommendations for books in the specified genre
            recommendations = recommend(book_title)
            recommended_books.extend(recommendations)

    return recommended_books

# # Allow the user to enter the genre
# genre_name = input("Enter the genre: ")
# genre_recommendations = recommend_genre(genre_name)

# # Print the recommended books
# for book in genre_recommendations:
#     print("Book Title:", book[0])
#     print("Book Author:", book[1])
#     print("Image URL:", book[2])
#     print()  # Empty line for separation

# %%
recommend_genre('Fiction')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Book-Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 recommend_genre('Fiction')
#
# ...

# %%
with open('recommend_genre.pkl', 'wb') as file:
        pickle.dump(recommend_genre, file)

# %%
pickle.dump(genre,open('genre.pkl', 'wb'))
# pickle.dump(books,open('books.pkl','wb'))
# pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
with open('genre_with_name.pkl', 'wb') as file:
        pickle.dump(genre_with_name, file)

# %%
import numpy as np
import pandas as pd

genre=pd.read_csv('GENRE.csv')


genre_with_name = genre.merge(books,on='ISBN')
def recommend_genre(genre_name):
    # Filter books by the specified genre
    genre_books = genre_with_name[genre_with_name['Genre'] == genre_name]

    # Create a list of book titles in the specified genre
    genre_book_titles = genre_books['Book-Title'].tolist()

    recommended_books = []

    for book_title in genre_book_titles:
        # Check if the book is in the user-item ratings matrix
        if book_title in pt.index:
            # Get recommendations for books in the specified genre
            recommendations = recommend(book_title)
            recommended_books.extend(recommendations)

    return recommended_books

# %%
recommend_genre('Romance')

# %%
with open('recommendations.pkl', 'wb') as file:
        pickle.dump( recommended_books, file)
